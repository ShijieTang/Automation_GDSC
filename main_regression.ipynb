# %% [markdown]
# # 1. Load Library
#
# In this section we import all the necessary libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import kagglehub
import pandas as pd
import os
import random
import pickle

from scipy.sparse import csr_matrix, vstack
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
# from xgboost import XGBRegressor                  # XGBoost for GPU processing
from sklearn.preprocessing import OneHotEncoder     # Support Sparse Matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay   # Classification metrics

print('Libraries loaded successfully')
# Out:
# Libraries loaded successfully

# %% [markdown]
# # 2. Load Dataset
#
# Load the dataset (e.g., a CSV file) and preview it.

# %%
# Download from Kaggle or load preprocessed data
current_path = None
if not current_path:
    path = kagglehub.dataset_download("samiraalipour/genomics-of-drug-sensitivity-in-cancer-gdsc")
else:
    path = current_path
print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.11), please consider upgrading to the latest version (0.3.12).
# Path to dataset files: /Users/shijie/.cache/kagglehub/datasets/samiraalipour/genomics-of-drug-sensitivity-in-cancer-gdsc/versions/2

# %%
from dataloader import load_gdsc, prepare_features, split_data
excluded_columns = ['LN_IC50', 'AUC', 'Z_SCORE', 'DRUG_ID', 'COSMIC_ID', 'DRUG_NAME', 'CELL_LINE_NAME']
df = load_gdsc(excluded_columns=excluded_columns)   # With Drop NaN & Exclude Outlier with IQR

# Create dummy variables for categorical features and split the data into training and testing sets with default test size of 0.2
X_dummy, y = prepare_features(df, encode_dummies=True)
X_label, _ = prepare_features(df, encode_dummies=False)
Xd_tr, Xd_te, Xl_tr, Xl_te, y_tr, y_te = split_data(X_dummy, X_label, y)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.11), please consider upgrading to the latest version (0.3.12).

# %%
df
# Out:
#         COSMIC_ID CELL_LINE_NAME TCGA_DESC  DRUG_ID          DRUG_NAME  \
# 0          683667         PFSK-1        MB     1003       Camptothecin
# 5          687448       COLO-829      SKCM     1003       Camptothecin
# 7          687455            RT4      BLCA     1003       Camptothecin
# 8          687457          SW780      BLCA     1003       Camptothecin
# 9          687459         TCCSUP      BLCA     1003       Camptothecin
# ...           ...            ...       ...      ...                ...
# 242029    1659818           MM1S        MM     2499  N-acetyl cysteine
# 242030    1659928        SNU-175    COREAD     2499  N-acetyl cysteine
# 242031    1660034        SNU-407    COREAD     2499  N-acetyl cysteine
# 242032    1660035         SNU-61    COREAD     2499  N-acetyl cysteine
# 242033    1674021         SNU-C5    COREAD     2499  N-acetyl cysteine
#
#          LN_IC50       AUC   Z_SCORE GDSC Tissue descriptor 1  \
# 0      -1.463887  0.930220  0.433123           nervous_system
# 5      -1.235034  0.867348  0.557727                     skin
# 7      -2.963191  0.821438 -0.383200        urogenital_system
# 8      -1.449138  0.905050  0.441154        urogenital_system
# 9      -2.350633  0.843430 -0.049682        urogenital_system
# ...          ...       ...       ...                      ...
# 242029  9.316959  0.988236 -0.775041                  myeloma
# 242030  9.686618  0.976746  0.156872          large_intestine
# 242031  8.576377  0.913378 -1.626959          large_intestine
# 242032  9.686618  0.975001  0.608442          large_intestine
# 242033  9.686618  0.969969  0.809684          large_intestine
#
#        GDSC Tissue descriptor 2 Cancer Type (matching TCGA label)  \
# 0               medulloblastoma                                MB
# 5                      melanoma                              SKCM
# 7                       Bladder                              BLCA
# 8                       Bladder                              BLCA
# 9                       Bladder                              BLCA
# ...                         ...                               ...
# 242029                  myeloma                                MM
# 242030          large_intestine                         COAD/READ
# 242031          large_intestine                         COAD/READ
# 242032          large_intestine                         COAD/READ
# 242033          large_intestine                         COAD/READ
#
#        Microsatellite instability Status (MSI) Screen Medium  \
# 0                                    MSS/MSI-L             R
# 5                                    MSS/MSI-L             R
# 7                                    MSS/MSI-L         D/F12
# 8                                    MSS/MSI-L         D/F12
# 9                                    MSS/MSI-L         D/F12
# ...                                        ...           ...
# 242029                               MSS/MSI-L             R
# 242030                                   MSI-H             R
# 242031                                   MSI-H             R
# 242032                               MSS/MSI-L             R
# 242033                                   MSI-H             R
#
#        Growth Properties CNA Gene Expression Methylation      TARGET  \
# 0               Adherent   Y               Y           Y        TOP1
# 5               Adherent   Y               Y           Y        TOP1
# 7               Adherent   Y               Y           Y        TOP1
# 8               Adherent   Y               Y           Y        TOP1
# 9               Adherent   Y               Y           Y        TOP1
# ...                  ...  ..             ...         ...         ...
# 242029        Suspension   Y               Y           Y  Metabolism
# 242030        Suspension   Y               Y           Y  Metabolism
# 242031          Adherent   Y               Y           Y  Metabolism
# 242032          Adherent   Y               Y           Y  Metabolism
# 242033          Adherent   Y               Y           Y  Metabolism
#
#          TARGET_PATHWAY
# 0       DNA replication
# 5       DNA replication
# 7       DNA replication
# 8       DNA replication
# 9       DNA replication
# ...                 ...
# 242029       Metabolism
# 242030       Metabolism
# 242031       Metabolism
# 242032       Metabolism
# 242033       Metabolism
#
# [166644 rows x 19 columns]

# %%
Xd_tr.shape
# Out:
# (16000, 336)

# %%
X_dummy.shape
# Out:
# (166644, 336)

# %% [markdown]
# # 3. Define Base Learner
#
# Define the base learner that will be used in the different learning methods. For example, a simple Logistic Regression classifier.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor

# Define the base learner as random forest
base_learner = XGBRegressor(
        n_estimators=100,
        learning_rate=0.15,
        max_depth=6,
        min_child_weight=3,
        subsample=0.8,
        colsample_bytree=0.8,
        gamma=0.2,
        reg_alpha=0.1,
        reg_lambda=1.0,
        objective='reg:squarederror',
        tree_method='hist',
        random_state=42,
        n_jobs=-1
    )

print('Base learner defined:')
print(base_learner)
# Out:
# Base learner defined:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=0.2, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.15, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=3, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=-1, num_parallel_tree=None, ...)

# %%
# PCA for dimensionality reduction
from sklearn.decomposition import PCA

pca = PCA(n_components=70)
Xd_pca = pca.fit_transform(Xd_tr)
Xd_te_pca = pca.transform(Xd_te)

# %% [markdown]
# # 4. Offline Learning Method
#
# Implement the offline (batch) learning method where the base learner is trained on the entire dataset.

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Train the base learner
base_learner.fit(Xl_tr, y_tr)

# evaluate the model
y_pred = base_learner.predict(X=Xl_te)
mse = mean_squared_error(y_te, y_pred)
r2 = r2_score(y_te, y_pred)
print(f'MSE of the model: {mse:.2f}')
print(f'r2 of the model: {r2:.2f}')

# Visualize the feature importance
importances = base_learner.feature_importances_
indices = np.argsort(importances)[::-1]
features = Xd_tr.columns[indices]
# features = X_encoded.columns[indices]
plt.figure(figsize=(10, 6))
plt.title("Feature importances")
plt.bar(range(len(features)), importances[indices], align="center")
plt.xticks(range(len(features)), features, rotation=90)
plt.xlim([-1, len(features)])
plt.tight_layout()
plt.show()
# Out:
# MSE of the model: 2.11
# r2 of the model: 0.69

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Train the base learner
base_learner.fit(Xl_tr, y_tr)

# evaluate the model
y_pred = base_learner.predict(Xl_te)
mse = mean_squared_error(y_te, y_pred)
r2 = r2_score(y_te, y_pred)
print(f'MSE of the model: {mse:.2f}')
print(f'r2 of the model: {r2:.2f}')

# Visualize the feature importance
importances = base_learner.feature_importances_
indices = np.argsort(importances)[::-1]
features = Xl_tr.columns[indices]
# features = X_encoded.columns[indices]
plt.figure(figsize=(10, 6))
plt.title("Feature importances")
plt.bar(range(len(features)), importances[indices], align="center")
plt.xticks(range(len(features)), features, rotation=90)
plt.xlim([-1, len(features)])
plt.tight_layout()
plt.show()
# Out:
# MSE of the model: 2.07
# r2 of the model: 0.71

# %% [markdown]
# # 5. Passive Learning Method
#
# Implement the passive learning method. This method randomly select instances from sample space for model training.

# %%
def random_sampling(X, y, n_samples, random_state):
    np.random.seed(random_state)
    indices = np.random.permutation(X.shape[0])
    sample_idx = indices[:n_samples]
    remaining_idx = indices[n_samples:]

    X_sampled = X.iloc[sample_idx]
    X_remaining = X.iloc[remaining_idx]

    y_sampled = y.iloc[sample_idx]
    y_remaining = y.iloc[remaining_idx]

    return X_sampled, X_remaining, y_sampled, y_remaining

# %%
from sklearn.metrics import mean_squared_error, r2_score
import warnings
from xgboost import XGBRegressor

warnings.filterwarnings(
    "ignore",
    message="X has feature names, but .* was fitted without feature names",
    category=UserWarning,
    module="sklearn.utils.validation"
)

mse_passive = []
r2_passive = []

initial_train_size = 0.05   # Percentage of data for initial training, excluding test set
n_runs = 5                  # Number of experiments

for seed in range(n_runs):
    base_learner = XGBRegressor(
        n_estimators=100,
        learning_rate=0.15,
        max_depth=6,
        min_child_weight=3,
        subsample=0.8,
        colsample_bytree=0.8,
        gamma=0.2,
        reg_alpha=0.1,
        reg_lambda=1.0,
        objective='reg:squarederror',
        tree_method='hist',
        random_state=42,
        n_jobs=-1
    )

    # Split the data into training, validation, and testing sets
    X_test, y_test = Xl_te.copy(), y_te.copy()

    X_train, X_pool, y_train, y_pool = train_test_split(
        Xl_tr, y_tr,
        train_size=initial_train_size,
        random_state=seed
    )

    overall_mse = []
    overall_r2  = []

    n = 0
    # add the most uncertain sample to the training set
    while X_pool.shape[0] > 0:
        # Train the model
        model = base_learner.fit(X_train, y_train)

        # Evaluate the model on the test set
        y_pred = model.predict(X_test)
        # Calculate the mean squared error and R^2 score
        overall_mse.append(mean_squared_error(y_test, y_pred))
        overall_r2.append(r2_score(y_test, y_pred))
        
        # Randomly select a sample from the training set
        X_new, X_pool, y_new, y_pool = random_sampling(
            X_pool, y_pool, n_samples=100, random_state=seed)

        # Update the training set with the new sample
        # X_train = vstack([X_train, X_new])
        X_train = pd.concat([X_train, X_new], ignore_index=True)
        y_train = pd.concat([y_train, y_new], ignore_index=True)
        # Verbose output
        if n % 10 == 0:
            print(f"Training size: {X_train.shape[0]}, MSE: {overall_mse[-1]:.2f}, R2: {overall_r2[-1]:.2f}")
        n += 1

    mse_passive.append(overall_mse)
    r2_passive.append(overall_r2)
    print(f"Seed {seed} done")
# Out:
# Training size: 900, MSE: 3.89, R2: 0.43
# Training size: 1900, MSE: 2.78, R2: 0.59
# Training size: 2900, MSE: 2.48, R2: 0.64
# Training size: 3900, MSE: 2.32, R2: 0.66
# Training size: 4900, MSE: 2.29, R2: 0.66
# Training size: 5900, MSE: 2.24, R2: 0.67
# Training size: 6900, MSE: 2.22, R2: 0.67
# Training size: 7900, MSE: 2.18, R2: 0.68
# Training size: 8900, MSE: 2.15, R2: 0.68
# Training size: 9900, MSE: 2.15, R2: 0.68
# Training size: 10900, MSE: 2.13, R2: 0.69
# Training size: 11900, MSE: 2.13, R2: 0.69
# Training size: 12900, MSE: 2.12, R2: 0.69
# Training size: 13900, MSE: 2.11, R2: 0.69
# Training size: 14900, MSE: 2.10, R2: 0.69
# Training size: 15900, MSE: 2.09, R2: 0.69
# Seed 0 done
# Training size: 900, MSE: 3.85, R2: 0.43
# Training size: 1900, MSE: 2.81, R2: 0.59
# Training size: 2900, MSE: 2.60, R2: 0.62
# Training size: 3900, MSE: 2.43, R2: 0.64
# Training size: 4900, MSE: 2.43, R2: 0.64
# Training size: 5900, MSE: 2.36, R2: 0.65
# Training size: 6900, MSE: 2.26, R2: 0.67
# Training size: 7900, MSE: 2.23, R2: 0.67
# Training size: 8900, MSE: 2.25, R2: 0.67
# Training size: 9900, MSE: 2.20, R2: 0.68
# Training size: 10900, MSE: 2.18, R2: 0.68
# Training size: 11900, MSE: 2.16, R2: 0.68
# Training size: 12900, MSE: 2.16, R2: 0.68
# Training size: 13900, MSE: 2.14, R2: 0.69
# Training size: 14900, MSE: 2.13, R2: 0.69
# Training size: 15900, MSE: 2.12, R2: 0.69
# Seed 1 done
# Training size: 900, MSE: 3.71, R2: 0.45
# Training size: 1900, MSE: 2.86, R2: 0.58
# Training size: 2900, MSE: 2.56, R2: 0.62
# Training size: 3900, MSE: 2.39, R2: 0.65
# Training size: 4900, MSE: 2.39, R2: 0.65
# Training size: 5900, MSE: 2.31, R2: 0.66
# Training size: 6900, MSE: 2.25, R2: 0.67
# Training size: 7900, MSE: 2.24, R2: 0.67
# Training size: 8900, MSE: 2.22, R2: 0.67
# Training size: 9900, MSE: 2.21, R2: 0.68
# Training size: 10900, MSE: 2.19, R2: 0.68
# Training size: 11900, MSE: 2.16, R2: 0.68
# Training size: 12900, MSE: 2.15, R2: 0.68
# Training size: 13900, MSE: 2.14, R2: 0.69
# Training size: 14900, MSE: 2.14, R2: 0.69
# Training size: 15900, MSE: 2.09, R2: 0.69
# Seed 2 done
# Training size: 900, MSE: 3.96, R2: 0.42
# Training size: 1900, MSE: 3.01, R2: 0.56
# Training size: 2900, MSE: 2.60, R2: 0.62
# Training size: 3900, MSE: 2.52, R2: 0.63
# Training size: 4900, MSE: 2.38, R2: 0.65
# Training size: 5900, MSE: 2.32, R2: 0.66
# Training size: 6900, MSE: 2.25, R2: 0.67
# Training size: 7900, MSE: 2.25, R2: 0.67
# Training size: 8900, MSE: 2.20, R2: 0.68
# Training size: 9900, MSE: 2.19, R2: 0.68
# Training size: 10900, MSE: 2.18, R2: 0.68
# Training size: 11900, MSE: 2.17, R2: 0.68
# Training size: 12900, MSE: 2.15, R2: 0.68
# Training size: 13900, MSE: 2.11, R2: 0.69
# Training size: 14900, MSE: 2.13, R2: 0.69
# Training size: 15900, MSE: 2.12, R2: 0.69
# Seed 3 done
# Training size: 900, MSE: 3.83, R2: 0.44
# Training size: 1900, MSE: 2.70, R2: 0.60
# Training size: 2900, MSE: 2.52, R2: 0.63
# Training size: 3900, MSE: 2.45, R2: 0.64
# Training size: 4900, MSE: 2.37, R2: 0.65
# Training size: 5900, MSE: 2.31, R2: 0.66
# Training size: 6900, MSE: 2.25, R2: 0.67
# Training size: 7900, MSE: 2.21, R2: 0.67
# Training size: 8900, MSE: 2.17, R2: 0.68
# Training size: 9900, MSE: 2.20, R2: 0.68
# Training size: 10900, MSE: 2.14, R2: 0.69
# Training size: 11900, MSE: 2.16, R2: 0.68
# Training size: 12900, MSE: 2.13, R2: 0.69
# Training size: 13900, MSE: 2.12, R2: 0.69
# Training size: 14900, MSE: 2.11, R2: 0.69
# Training size: 15900, MSE: 2.11, R2: 0.69
# Seed 4 done

# %%
# Calculate the mean and standard deviation of MSE and R^2 scores
mse_passive = np.array(mse_passive)
mean_mse_passive = np.mean(mse_passive, axis=0)
std_mse_passive = np.std(mse_passive, axis=0)
r2_passive = np.array(r2_passive)
mean_r2_passive = np.mean(r2_passive, axis=0)
std_r2_passive = np.std(r2_passive, axis=0)
print(f'Mean MSE of the model: {mean_mse_passive[-1]:.2f}')
print(f'Mean r2 of the model: {mean_r2_passive[-1]:.2f}')
n_points = len(mean_mse_passive)
x_vals = 6765 + np.arange(n_points) * 1000

# Plot the results
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(x_vals, mean_mse_passive, label='Passive Learning')
plt.fill_between(x_vals, mean_mse_passive - std_mse_passive,
                 mean_mse_passive + std_mse_passive, alpha=0.2)
plt.xlabel('Number of samples')
plt.ylabel('Mean Squared Error')
plt.title('Passive Learning MSE')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(x_vals, mean_r2_passive, label='Passive Learning')
plt.fill_between(x_vals, mean_r2_passive - std_r2_passive,
                 mean_r2_passive + std_r2_passive, alpha=0.2)
plt.xlabel('Number of samples')
plt.ylabel('R^2 Score')
plt.title('Passive Learning R^2 Score')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Mean MSE of the model: 2.02
# Mean r2 of the model: 0.71

# %% [markdown]
# # 6. Active Learning Method
#
# ### 6.1 Uncertainty based method

# %%
def uncertainty_sampling_ensemble(models, X_pool, y_pool, n_samples):
    # shape = (n_models, n_pool_samples)
    all_preds = np.vstack([m.predict(X_pool) for m in models])
    # shape = (n_pool_samples,)
    variances = np.var(all_preds, axis=0)
    
    # sort the indices based on uncertainty and noise
    order = np.argsort(-variances)
    sampled_idx   = order[:n_samples]
    remaining_idx = order[n_samples:]
    
    # separate sampled and remaining datasets
    X_sampled   = X_pool.iloc[sampled_idx]   if hasattr(X_pool, 'iloc') else X_pool[sampled_idx]
    X_remaining = X_pool.iloc[remaining_idx] if hasattr(X_pool, 'iloc') else X_pool[remaining_idx]
    y_sampled   = y_pool.iloc[sampled_idx]   if hasattr(y_pool, 'iloc') else y_pool[sampled_idx]
    y_remaining = y_pool.iloc[remaining_idx] if hasattr(y_pool, 'iloc') else y_pool[remaining_idx]
    
    return X_sampled, X_remaining, y_sampled, y_remaining

# %%
def train_ensemble(X_train, y_train, n_models=5, **xgb_kwargs):
    models = []
    for seed in range(n_models):
        m = XGBRegressor(
            random_state=seed,
            **xgb_kwargs)
        m.fit(X_train, y_train)
        models.append(m)
    return models

# %%
test_size = 0.2             # Percentage of data for testing
initial_train_size = 0.05   # Percentage of data for initial training, excluding test set
max_train_size = 1.00       # Percentage of data for maximum training size, excluding test set 
n_runs = 5                  # Number of experiments

mse_uncertainty = []
r2_uncertainty = []

for seed in range(n_runs):
    # Split the data into training, validation, and testing sets
    X_test, y_test = Xl_te.copy(), y_te.copy()

    X_train, X_pool, y_train, y_pool = train_test_split(
        Xl_tr, y_tr,
        train_size=initial_train_size,
        random_state=seed)
    overall_mse = []
    overall_r2 = []
    n=0
    while X_pool.shape[0] >0 :
        models = train_ensemble(
            X_train, y_train,
            n_models=5,
            n_estimators=100,
            max_depth=6,
            learning_rate=0.15,
            subsample=0.8,
            colsample_bytree=0.8,
            gamma=0.2,
            reg_alpha=0.1,
            reg_lambda=1.0,
            objective='reg:squarederror',
            tree_method='hist'
        )

        y_pred = np.mean([m.predict(X_test) for m in models], axis=0)
        overall_mse.append(mean_squared_error(y_test, y_pred))
        overall_r2 .append(r2_score(y_test, y_pred))

        # Randomly select a sample from the training set
        X_new, X_pool, y_new, y_pool = uncertainty_sampling_ensemble(
            models, X_pool, y_pool, n_samples=100)

        # Update the training set with the new sample
        X_train = pd.concat([X_train, X_new], ignore_index=True)
        y_train = pd.concat([y_train, y_new], ignore_index=True)

        # Verbose output
        if n % 10 == 0:
            print(f"Training size: {X_train.shape[0]}, MSE: {overall_mse[-1]:.2f}, R2: {overall_r2[-1]:.2f}")
        n += 1

    mse_uncertainty.append(overall_mse)
    r2_uncertainty.append(overall_r2)
    print(f"Seed {seed} done")
# Out:
# Training size: 900, MSE: 3.82, R2: 0.44
# Training size: 1900, MSE: 2.82, R2: 0.59
# Training size: 2900, MSE: 2.54, R2: 0.63
# Training size: 3900, MSE: 2.44, R2: 0.64
# Training size: 4900, MSE: 2.38, R2: 0.65
# Training size: 5900, MSE: 2.29, R2: 0.66
# Training size: 6900, MSE: 2.23, R2: 0.67
# Training size: 7900, MSE: 2.20, R2: 0.68
# Training size: 8900, MSE: 2.18, R2: 0.68
# Training size: 9900, MSE: 2.17, R2: 0.68
# Training size: 10900, MSE: 2.15, R2: 0.68
# Training size: 11900, MSE: 2.13, R2: 0.69
# Training size: 12900, MSE: 2.12, R2: 0.69
# Training size: 13900, MSE: 2.11, R2: 0.69
# Training size: 14900, MSE: 2.11, R2: 0.69
# Training size: 15900, MSE: 2.11, R2: 0.69
# Seed 0 done
# Training size: 900, MSE: 3.82, R2: 0.44
# Training size: 1900, MSE: 2.84, R2: 0.58
# Training size: 2900, MSE: 2.53, R2: 0.63
# Training size: 3900, MSE: 2.38, R2: 0.65
# Training size: 4900, MSE: 2.32, R2: 0.66
# Training size: 5900, MSE: 2.26, R2: 0.67
# Training size: 6900, MSE: 2.24, R2: 0.67
# Training size: 7900, MSE: 2.20, R2: 0.68
# Training size: 8900, MSE: 2.18, R2: 0.68
# Training size: 9900, MSE: 2.16, R2: 0.68
# Training size: 10900, MSE: 2.15, R2: 0.68
# Training size: 11900, MSE: 2.12, R2: 0.69
# Training size: 12900, MSE: 2.13, R2: 0.69
# Training size: 13900, MSE: 2.11, R2: 0.69
# Training size: 14900, MSE: 2.11, R2: 0.69
# Training size: 15900, MSE: 2.12, R2: 0.69
# Seed 1 done
# Training size: 900, MSE: 3.64, R2: 0.46
# Training size: 1900, MSE: 2.80, R2: 0.59
# Training size: 2900, MSE: 2.52, R2: 0.63
# Training size: 3900, MSE: 2.40, R2: 0.65
# Training size: 4900, MSE: 2.31, R2: 0.66
# Training size: 5900, MSE: 2.28, R2: 0.66
# Training size: 6900, MSE: 2.24, R2: 0.67
# Training size: 7900, MSE: 2.20, R2: 0.68
# Training size: 8900, MSE: 2.21, R2: 0.68
# Training size: 9900, MSE: 2.19, R2: 0.68
# Training size: 10900, MSE: 2.16, R2: 0.68
# Training size: 11900, MSE: 2.15, R2: 0.68
# Training size: 12900, MSE: 2.15, R2: 0.68
# Training size: 13900, MSE: 2.14, R2: 0.69
# Training size: 14900, MSE: 2.12, R2: 0.69
# Training size: 15900, MSE: 2.12, R2: 0.69
# Seed 2 done
# Training size: 900, MSE: 3.83, R2: 0.44
# Training size: 1900, MSE: 2.76, R2: 0.59
# Training size: 2900, MSE: 2.51, R2: 0.63
# Training size: 3900, MSE: 2.33, R2: 0.66
# Training size: 4900, MSE: 2.28, R2: 0.67
# Training size: 5900, MSE: 2.22, R2: 0.67
# Training size: 6900, MSE: 2.20, R2: 0.68
# Training size: 7900, MSE: 2.18, R2: 0.68
# Training size: 8900, MSE: 2.17, R2: 0.68
# Training size: 9900, MSE: 2.15, R2: 0.68
# Training size: 10900, MSE: 2.13, R2: 0.69
# Training size: 11900, MSE: 2.12, R2: 0.69
# Training size: 12900, MSE: 2.11, R2: 0.69
# Training size: 13900, MSE: 2.11, R2: 0.69
# Training size: 14900, MSE: 2.11, R2: 0.69
# Training size: 15900, MSE: 2.11, R2: 0.69
# Seed 3 done
# Training size: 900, MSE: 3.76, R2: 0.45
# Training size: 1900, MSE: 2.71, R2: 0.60
# Training size: 2900, MSE: 2.45, R2: 0.64
# Training size: 3900, MSE: 2.32, R2: 0.66
# Training size: 4900, MSE: 2.28, R2: 0.66
# Training size: 5900, MSE: 2.24, R2: 0.67
# Training size: 6900, MSE: 2.21, R2: 0.68
# Training size: 7900, MSE: 2.19, R2: 0.68
# Training size: 8900, MSE: 2.17, R2: 0.68
# Training size: 9900, MSE: 2.16, R2: 0.68
# Training size: 10900, MSE: 2.16, R2: 0.68
# Training size: 11900, MSE: 2.14, R2: 0.69
# Training size: 12900, MSE: 2.13, R2: 0.69
# Training size: 13900, MSE: 2.13, R2: 0.69
# Training size: 14900, MSE: 2.12, R2: 0.69
# Training size: 15900, MSE: 2.12, R2: 0.69
# Seed 4 done

# %%
# Calculate the mean and standard deviation of accuracy and F1 scores
mse_uncertainty = np.array(mse_uncertainty)
mean_mse_uncertainty = np.mean(mse_uncertainty, axis=0)
std_mse_uncertainty = np.std(mse_uncertainty, axis=0)
r2_uncertainty = np.array(r2_uncertainty)
mean_r2_uncertainty = np.mean(r2_uncertainty, axis=0)
std_r2_uncertainty = np.std(r2_uncertainty, axis=0)
print(f'Mean MSE of the model: {mean_mse_uncertainty[-1]:.4f}')
print(f'Mean R2 Score of the model: {mean_r2_uncertainty[-1]:.4f}')
n_points = len(mean_mse_uncertainty)
x_vals = 6765 + np.arange(n_points) * 1000

# Plot the results
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(x_vals, mean_mse_uncertainty, label='Uncertainty sampling')
plt.fill_between(x_vals, mean_mse_uncertainty - std_mse_uncertainty,
                 mean_mse_uncertainty + std_mse_uncertainty, alpha=0.2)
plt.xlabel('Number of samples')
plt.ylabel('Mean Squared Error')
plt.title('Uncertainty sampling MSE')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(x_vals, mean_r2_uncertainty, label='Uncertainty sampling')
plt.fill_between(x_vals, mean_r2_uncertainty - std_r2_uncertainty,
                 mean_r2_uncertainty + std_r2_uncertainty, alpha=0.2)
plt.xlabel('Number of samples')
plt.ylabel('R^2 Score')
plt.title('Uncertainty sampling R^2 Score')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Mean MSE of the model: 2.0102
# Mean R2 Score of the model: 0.7150

# %%
from sklearn.metrics.pairwise import cosine_similarity
def density_batch_selection(models, X_pool, batch_size=100):
    # calculate the density of the pool
    print('Calculating density of the pool...')
    S = cosine_similarity(X_pool)
    density = S.mean(axis=1)

    # calculate the uncertainty of the pool
    preds = np.stack([m.predict(X_pool) for m in models], axis=0)
    utility = preds.var(axis=0)  

    # score = utility * density
    score = utility * density

    # select the samples with the highest score
    selected_idx = np.argsort(-score)[:batch_size]
    return selected_idx

# %%
def train_ensemble(X_train, y_train, n_models=5, **xgb_kwargs):
    models = []
    for seed in range(n_models):
        m = XGBRegressor(
            random_state=seed,
            **xgb_kwargs
        )
        m.fit(X_train, y_train)
        models.append(m)
    return models

# %%
from sklearn.metrics import mean_squared_error, r2_score
import warnings
from xgboost import XGBRegressor

test_size = 0.2             # Percentage of data for testing
initial_train_size = 0.05   # Percentage of data for initial training, excluding test set
max_train_size = 1.00       # Percentage of data for maximum training size, excluding test set 
n_runs = 5                  # Number of experiments

mse_dst = []
r2_dst = []

for seed in range(n_runs):
    # Split the data into training, validation, and testing sets
    X_test, y_test = Xl_te.copy(), y_te.copy()

    X_train, X_pool, y_train, y_pool = train_test_split(
        Xl_tr, y_tr,
        train_size=initial_train_size,
        random_state=seed)
    overall_mse = []
    overall_r2 = []
    n=0

    while X_pool.shape[0] >0 :
        models = train_ensemble(
            X_train, y_train,
            n_models=5,
            n_estimators=100,
            max_depth=6,
            learning_rate=0.15,
            subsample=0.8,
            colsample_bytree=0.8,
            gamma=0.2,
            reg_alpha=0.1,
            reg_lambda=1.0,
            objective='reg:squarederror',
            tree_method='hist'
            )

        # Evaluate the model on the test set
        y_pred = np.mean([m.predict(X_test) for m in models], axis=0)
        overall_mse.append(mean_squared_error(y_test, y_pred))
        overall_r2 .append(r2_score(y_test, y_pred))

        selected = density_batch_selection(models,X_pool.values if hasattr(X_pool, 'values') else X_pool,100)

        # Select the first 100 samples for training
        X_new = X_pool.iloc[selected]
        y_new = y_pool.iloc[selected]
        X_pool = X_pool.drop(X_pool.index[selected]).reset_index(drop=True)
        y_pool = y_pool.drop(y_pool.index[selected]).reset_index(drop=True)

        # Update the training set with the new sample
        X_train = pd.concat([X_train, X_new], ignore_index=True)
        y_train = pd.concat([y_train, y_new], ignore_index=True)

        # Verbose output
        if n % 100 == 0:
            print(f"Training size: {X_train.shape[0]}, MSE: {overall_mse[-1]:.2f}, R2: {overall_r2[-1]:.2f}")
        n += 1

    mse_doe.append(overall_mse)
    r2_doe.append(overall_r2)
    print(f"Seed {seed} done")
# Out:
# Calculating density of the pool...
# Training size: 900, MSE: 3.82, R2: 0.44
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Training size: 10900, MSE: 2.16, R2: 0.68
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Seed 0 done
# Calculating density of the pool...
# Training size: 900, MSE: 3.82, R2: 0.44
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Training size: 10900, MSE: 2.14, R2: 0.69
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Seed 1 done
# Calculating density of the pool...
# Training size: 900, MSE: 3.64, R2: 0.46
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Training size: 10900, MSE: 2.15, R2: 0.68
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Seed 2 done
# Calculating density of the pool...
# Training size: 900, MSE: 3.83, R2: 0.44
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Training size: 10900, MSE: 2.12, R2: 0.69
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Seed 3 done
# Calculating density of the pool...
# Training size: 900, MSE: 3.76, R2: 0.45
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Training size: 10900, MSE: 2.15, R2: 0.68
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Calculating density of the pool...
# Seed 4 done

# %% [markdown]
# ## Expected model change

# %%
from sklearn.base import clone
def estimate_utilities_eer(model, X_train, y_train, X_test, y_test,
                           X_pool, candidate_idx, n_extra_rounds=10, **xgb_kwargs):
    """
    For each index in candidate_idx, simulate adding that point (with its predicted label)
    to the training set, retrain for n_extra_rounds, and measure MSE reduction on (X_test,y_test).
    Returns a list of (idx, utility) tuples.
    """
    base_mse = mean_squared_error(y_test, model.predict(X_test))
    utilities = []
    # We'll retrain clones of the model for a small extra number of rounds
    for i in candidate_idx:
        x_i = X_pool.iloc[[i]]
        # 1) predict its pseudo-label
        y_hat = model.predict(x_i)[0]
        # 2) build augmented train set
        X_aug = pd.concat([X_train, x_i], ignore_index=True)
        y_aug = pd.concat([y_train, pd.Series([y_hat])], ignore_index=True)
        # 3) clone and continue training
        m = clone(model)
        # continue training for n_extra_rounds:
        # note: sklearn API allows xgb_model to warm-start
        m.set_params(n_estimators=n_extra_rounds, **xgb_kwargs)
        # pass the original booster as xgb_model to warm-start
        m.fit(X_aug, y_aug,
              xgb_model=model.get_booster(),
              verbose=False)
        # 4) measure new MSE
        new_mse = mean_squared_error(y_test, m.predict(X_test))
        utilities.append((i, base_mse - new_mse))
    return utilities

# %%
def eer_batch_selection(model, X_train, y_train, X_test, y_test,
                        X_pool, batch_size=100, pool_subset=500,
                        n_extra_rounds=10, **xgb_kwargs):
    """
    1) Sample up to pool_subset candidates from X_pool
    2) Estimate their Expected Error Reduction utilities
    3) Return the top batch_size indices (relative to X_pool)
    """
    # randomly subsample candidate indices for speed
    all_idx = np.arange(len(X_pool))
    if len(all_idx) > pool_subset:
        cand_idx = np.random.choice(all_idx, size=pool_subset, replace=False)
    else:
        cand_idx = all_idx

    utils = estimate_utilities_eer(
        model, X_train, y_train, X_test, y_test,
        X_pool, cand_idx,
        n_extra_rounds=n_extra_rounds,
        **xgb_kwargs)
    # pick top utilities
    utils.sort(key=lambda x: x[1], reverse=True)
    selected = [idx for idx, u in utils[:batch_size]]
    return selected

# %%
from sklearn.metrics import mean_squared_error, r2_score
import warnings
from xgboost import XGBRegressor

test_size = 0.2             # Percentage of data for testing
initial_train_size = 0.05   # Percentage of data for initial training, excluding test set
max_train_size = 1.00       # Percentage of data for maximum training size, excluding test set 
n_runs = 5                  # Number of experiments

mse_eer = []
r2_eer = []

for seed in range(n_runs):
    # Split the data into training, validation, and testing sets
    X_test, y_test = Xl_te.copy(), y_te.copy()

    X_train, X_pool, y_train, y_pool = train_test_split(
        Xl_tr, y_tr,
        train_size=initial_train_size,
        random_state=seed)
    overall_mse = []
    overall_r2 = []
    n=0
    base_learner = XGBRegressor(
        n_estimators=100,
        learning_rate=0.15,
        max_depth=6,
        min_child_weight=3,
        subsample=0.8,
        colsample_bytree=0.8,
        gamma=0.2,
        reg_alpha=0.1,
        reg_lambda=1.0,
        objective='reg:squarederror',
        tree_method='hist',
        random_state=42,
        n_jobs=-1
    )

    pool_subset = 500
    extra_rounds = 5

    while len(X_pool) > 0:
        model = base_learner.fit(X_train, y_train)
        # Evaluate the model on the test set
        y_pred = model.predict(X_test)
        overall_mse.append(mean_squared_error(y_test, y_pred))
        overall_r2 .append(r2_score(y_test, y_pred))

        selected = eer_batch_selection(
            base_learner,
            X_train, y_train,
            X_test, y_test,
            X_pool,
            batch_size=100,
            pool_subset=pool_subset,
            n_extra_rounds=extra_rounds,
            max_depth=6,
            learning_rate=0.15,
            subsample=0.8,
            colsample_bytree=0.8,
            gamma=0.2,
            reg_alpha=0.1,
            reg_lambda=1.0,
            objective='reg:squarederror',
            tree_method='hist',
            random_state=seed
        )

        # Select the first 100 samples for training
        X_new = X_pool.iloc[selected]
        y_new = y_pool.iloc[selected]
        X_pool = X_pool.drop(X_pool.index[selected]).reset_index(drop=True)
        y_pool = y_pool.drop(y_pool.index[selected]).reset_index(drop=True)

        # Update the training set with the new sample
        X_train = pd.concat([X_train, X_new], ignore_index=True)
        y_train = pd.concat([y_train, y_new], ignore_index=True)

        # Verbose output
        if n % 10 == 0:
            print(f"Training size: {X_train.shape[0]}, MSE: {overall_mse[-1]:.2f}, R2: {overall_r2[-1]:.2f}")
        n += 1

    mse_eer.append(overall_mse)
    r2_eer.append(overall_r2)
    print(f"Seed {seed} done")
# Out:
# Training size: 900, MSE: 3.89, R2: 0.43
# Training size: 1900, MSE: 2.88, R2: 0.58
# Training size: 2900, MSE: 2.59, R2: 0.62
# Training size: 3900, MSE: 2.49, R2: 0.63
# Training size: 4900, MSE: 2.40, R2: 0.65
# Training size: 5900, MSE: 2.35, R2: 0.65
# Training size: 6900, MSE: 2.28, R2: 0.66
# Training size: 7900, MSE: 2.23, R2: 0.67
# Training size: 8900, MSE: 2.26, R2: 0.67
# Training size: 9900, MSE: 2.16, R2: 0.68
# Training size: 10900, MSE: 2.19, R2: 0.68
# Training size: 11900, MSE: 2.19, R2: 0.68
# Training size: 12900, MSE: 2.17, R2: 0.68
# Training size: 13900, MSE: 2.14, R2: 0.69
# Training size: 14900, MSE: 2.13, R2: 0.69
# Training size: 15900, MSE: 2.13, R2: 0.69
# Seed 0 done
# Training size: 900, MSE: 3.85, R2: 0.43
# Training size: 1900, MSE: 3.07, R2: 0.55
# Training size: 2900, MSE: 2.66, R2: 0.61
# Training size: 3900, MSE: 2.58, R2: 0.62
# Training size: 4900, MSE: 2.46, R2: 0.64
# Training size: 5900, MSE: 2.35, R2: 0.65
# Training size: 6900, MSE: 2.30, R2: 0.66
# Training size: 7900, MSE: 2.25, R2: 0.67
# Training size: 8900, MSE: 2.25, R2: 0.67
# Training size: 9900, MSE: 2.21, R2: 0.67
# Training size: 10900, MSE: 2.19, R2: 0.68
# Training size: 11900, MSE: 2.18, R2: 0.68
# Training size: 12900, MSE: 2.18, R2: 0.68
# Training size: 13900, MSE: 2.15, R2: 0.68
# Training size: 14900, MSE: 2.12, R2: 0.69
# Training size: 15900, MSE: 2.11, R2: 0.69
# Seed 1 done
# Training size: 900, MSE: 3.71, R2: 0.45
# Training size: 1900, MSE: 2.72, R2: 0.60
# Training size: 2900, MSE: 2.46, R2: 0.64
# Training size: 3900, MSE: 2.38, R2: 0.65
# Training size: 4900, MSE: 2.33, R2: 0.66
# Training size: 5900, MSE: 2.31, R2: 0.66
# Training size: 6900, MSE: 2.28, R2: 0.67
# Training size: 7900, MSE: 2.23, R2: 0.67
# Training size: 8900, MSE: 2.22, R2: 0.67
# Training size: 9900, MSE: 2.19, R2: 0.68
# Training size: 10900, MSE: 2.17, R2: 0.68
# Training size: 11900, MSE: 2.17, R2: 0.68
# Training size: 12900, MSE: 2.13, R2: 0.69
# Training size: 13900, MSE: 2.15, R2: 0.68
# Training size: 14900, MSE: 2.12, R2: 0.69
# Training size: 15900, MSE: 2.12, R2: 0.69
# Seed 2 done
# Training size: 900, MSE: 3.96, R2: 0.42
# Training size: 1900, MSE: 2.90, R2: 0.57
# Training size: 2900, MSE: 2.66, R2: 0.61
# Training size: 3900, MSE: 2.46, R2: 0.64
# Training size: 4900, MSE: 2.41, R2: 0.65
# Training size: 5900, MSE: 2.31, R2: 0.66
# Training size: 6900, MSE: 2.30, R2: 0.66
# Training size: 7900, MSE: 2.25, R2: 0.67
# Training size: 8900, MSE: 2.21, R2: 0.67
# Training size: 9900, MSE: 2.20, R2: 0.68
# Training size: 10900, MSE: 2.18, R2: 0.68
# Training size: 11900, MSE: 2.18, R2: 0.68
# Training size: 12900, MSE: 2.16, R2: 0.68
# Training size: 13900, MSE: 2.16, R2: 0.68
# Training size: 14900, MSE: 2.14, R2: 0.69
# Training size: 15900, MSE: 2.14, R2: 0.69
# Seed 3 done
# Training size: 900, MSE: 3.83, R2: 0.44
# Training size: 1900, MSE: 2.82, R2: 0.59
# Training size: 2900, MSE: 2.57, R2: 0.62
# Training size: 3900, MSE: 2.42, R2: 0.64
# Training size: 4900, MSE: 2.35, R2: 0.65
# Training size: 5900, MSE: 2.28, R2: 0.66
# Training size: 6900, MSE: 2.32, R2: 0.66
# Training size: 7900, MSE: 2.23, R2: 0.67
# Training size: 8900, MSE: 2.20, R2: 0.68
# Training size: 9900, MSE: 2.21, R2: 0.68
# Training size: 10900, MSE: 2.17, R2: 0.68
# Training size: 11900, MSE: 2.13, R2: 0.69
# Training size: 12900, MSE: 2.12, R2: 0.69
# Training size: 13900, MSE: 2.13, R2: 0.69
# Training size: 14900, MSE: 2.11, R2: 0.69
# Training size: 15900, MSE: 2.09, R2: 0.69
# Seed 4 done

# %% [markdown]
# ## Black-box Batch

# %%
import numpy as np
from sklearn_extra.cluster import KMedoids
import pandas as pd

def batch_selection_blackbox(models,
                             X_pool,
                             batch_size,
                             pool_subset=1000,
                             random_state=None):
    # 1) Convert to numpy for positional indexing
    if isinstance(X_pool, pd.DataFrame):
        X_arr = X_pool.values
    else:
        X_arr = np.asarray(X_pool)
    n_pool = X_arr.shape[0]

    # 2) Subsample pool to limit compute
    rng = np.random.RandomState(random_state)
    if n_pool > pool_subset:
        sampled_idx = rng.choice(n_pool, size=pool_subset, replace=False)
    else:
        sampled_idx = np.arange(n_pool)
    X_sampled = X_arr[sampled_idx]

    # 3) Ensemble predictions
    preds = np.vstack([m.predict(X_sampled) for m in models])

    # 4) Uncertainty = variance across ensemble
    uncertainty = np.var(preds, axis=0)

    # 5) Over-select top-k by uncertainty
    topk = min(len(uncertainty), batch_size * 5)
    sorted_unc = np.argsort(-uncertainty)
    topk_pos = sorted_unc[:topk]
    X_cand = X_sampled[topk_pos]

    # 6) If too few candidates for clustering, just take the top batch_size uncertain
    if topk <= batch_size:
        pick = sorted_unc[:min(batch_size, len(uncertainty))]
        return sampled_idx[pick]

    # 7) Otherwise, cluster the top candidates and pick medoids
    kmedoids = KMedoids(
        n_clusters=batch_size,
        method='pam',
        init='heuristic',
        random_state=random_state
    ).fit(X_cand)

    medoid_pos = kmedoids.medoid_indices_  # positions within X_cand (0..topk-1)
    # map back to positions within X_sampled
    final_pos_in_sample = topk_pos[medoid_pos]
    return sampled_idx[final_pos_in_sample]

# %%
def train_ensemble(X_train, y_train, n_models=5, **xgb_kwargs):
    models = []
    for seed in range(n_models):
        m = XGBRegressor(
            random_state=seed,
            **xgb_kwargs
        )
        m.fit(X_train, y_train)
        models.append(m)
    return models

# %%
test_size = 0.2
initial_train_size = 0.05
max_train_size = 1.00
n_runs = 5

batch_size = 100
pool_subset = 500

mse_blackbox = []
r2_blackbox = []

for seed in range(n_runs):
    X_test, y_test = Xl_te.copy(), y_te.copy()
    X_train, X_pool, y_train, y_pool = train_test_split(
        Xl_tr, y_tr, train_size=initial_train_size, random_state=seed)

    overall_mse = []
    overall_r2  = []
    iteration = 0

    while len(X_pool) > 0:
        # Train ensemble
        ensemble = train_ensemble(
            X_train, y_train,
            n_models=5,
            n_estimators=100,
            max_depth=6,
            learning_rate=0.15,
            subsample=0.8,
            colsample_bytree=0.8,
            gamma=0.2,
            reg_alpha=0.1,
            reg_lambda=1.0,
            objective='reg:squarederror',
            tree_method='hist'
        )

        # Evaluate
        y_pred = np.mean([m.predict(X_test) for m in ensemble], axis=0)
        overall_mse.append(mean_squared_error(y_test, y_pred))
        overall_r2.append(r2_score(y_test, y_pred))

        # Select batch using black-box batch active learning
        selected = batch_selection_blackbox(
            ensemble,
            X_pool,
            batch_size=batch_size,
            pool_subset=pool_subset)


        # Add selected points
        X_new = X_pool.iloc[selected]
        y_new = y_pool.iloc[selected]
        X_pool = X_pool.drop(X_pool.index[selected]).reset_index(drop=True)
        y_pool = y_pool.drop(y_pool.index[selected]).reset_index(drop=True)

        X_train = pd.concat([X_train, X_new], ignore_index=True)
        y_train = pd.concat([y_train, y_new], ignore_index=True)

        if iteration % 10 == 0:
            print(f"Train size={len(X_train):4d}, "
                  f"MSE={overall_mse[-1]:.3f}, R2={overall_r2[-1]:.3f}")
        iteration += 1

    mse_blackbox.append(overall_mse)
    r2_blackbox.append(overall_r2)
    print(f"Seed {seed} done: Final MSE={overall_mse[-1]:.3f}, R2={overall_r2[-1]:.3f}\n")
# Out:
# Train size= 900, MSE=3.824, R2=0.438
# Train size=1900, MSE=2.768, R2=0.593
# Train size=2900, MSE=2.523, R2=0.629
# Train size=3900, MSE=2.440, R2=0.641
# Train size=4900, MSE=2.344, R2=0.655
# Train size=5900, MSE=2.294, R2=0.663
# Train size=6900, MSE=2.245, R2=0.670
# Train size=7900, MSE=2.213, R2=0.675
# Train size=8900, MSE=2.209, R2=0.675
# Train size=9900, MSE=2.187, R2=0.679
# Train size=10900, MSE=2.175, R2=0.680
# Train size=11900, MSE=2.171, R2=0.681
# Train size=12900, MSE=2.143, R2=0.685
# Train size=13900, MSE=2.141, R2=0.685
# Train size=14900, MSE=2.129, R2=0.687
# Train size=15900, MSE=2.112, R2=0.690
# Seed 0 done: Final MSE=2.114, R2=0.689
#
# Train size= 900, MSE=3.820, R2=0.438
# Train size=1900, MSE=2.917, R2=0.571
# Train size=2900, MSE=2.561, R2=0.624
# Train size=3900, MSE=2.414, R2=0.645
# Train size=4900, MSE=2.321, R2=0.659
# Train size=5900, MSE=2.274, R2=0.666
# Train size=6900, MSE=2.242, R2=0.670
# Train size=7900, MSE=2.195, R2=0.677
# Train size=8900, MSE=2.182, R2=0.679
# Train size=9900, MSE=2.178, R2=0.680
# Train size=10900, MSE=2.170, R2=0.681
# Train size=11900, MSE=2.154, R2=0.683
# Train size=12900, MSE=2.161, R2=0.682
# Train size=13900, MSE=2.155, R2=0.683
# Train size=14900, MSE=2.147, R2=0.684
# Train size=15900, MSE=2.126, R2=0.688
# Seed 1 done: Final MSE=2.119, R2=0.688
#
# Train size= 900, MSE=3.642, R2=0.465
# Train size=1900, MSE=2.940, R2=0.568
# Train size=2900, MSE=2.731, R2=0.599
# Train size=3900, MSE=2.604, R2=0.617
# Train size=4900, MSE=2.478, R2=0.636
# Train size=5900, MSE=2.376, R2=0.651
# Train size=6900, MSE=2.301, R2=0.662
# Train size=7900, MSE=2.253, R2=0.669
# Train size=8900, MSE=2.217, R2=0.674
# Train size=9900, MSE=2.183, R2=0.679
# Train size=10900, MSE=2.171, R2=0.681
# Train size=11900, MSE=2.163, R2=0.682
# Train size=12900, MSE=2.158, R2=0.683
# Train size=13900, MSE=2.144, R2=0.685
# Train size=14900, MSE=2.130, R2=0.687
# Train size=15900, MSE=2.117, R2=0.689
# Seed 2 done: Final MSE=2.109, R2=0.690
#
# Train size= 900, MSE=3.835, R2=0.436
# Train size=1900, MSE=2.857, R2=0.580
# Train size=2900, MSE=2.541, R2=0.627
# Train size=3900, MSE=2.411, R2=0.646
# Train size=4900, MSE=2.378, R2=0.650
# Train size=5900, MSE=2.299, R2=0.662
# Train size=6900, MSE=2.259, R2=0.668
# Train size=7900, MSE=2.217, R2=0.674
# Train size=8900, MSE=2.169, R2=0.681
# Train size=9900, MSE=2.214, R2=0.675
# Train size=10900, MSE=2.198, R2=0.677
# Train size=11900, MSE=2.172, R2=0.681
# Train size=12900, MSE=2.143, R2=0.685
# Train size=13900, MSE=2.126, R2=0.687
# Train size=14900, MSE=2.108, R2=0.690
# Train size=15900, MSE=2.119, R2=0.689
# Seed 3 done: Final MSE=2.108, R2=0.690
#
# Train size= 900, MSE=3.764, R2=0.447
# Train size=1900, MSE=2.830, R2=0.584
# Train size=2900, MSE=2.619, R2=0.615
# Train size=3900, MSE=2.378, R2=0.650
# Train size=4900, MSE=2.326, R2=0.658
# Train size=5900, MSE=2.264, R2=0.667
# Train size=6900, MSE=2.201, R2=0.677
# Train size=7900, MSE=2.200, R2=0.677
# Train size=8900, MSE=2.182, R2=0.679
# Train size=9900, MSE=2.160, R2=0.682
# Train size=10900, MSE=2.150, R2=0.684
# Train size=11900, MSE=2.143, R2=0.685
# Train size=12900, MSE=2.135, R2=0.686
# Train size=13900, MSE=2.122, R2=0.688
# Train size=14900, MSE=2.119, R2=0.689
# Train size=15900, MSE=2.110, R2=0.690
# Seed 4 done: Final MSE=2.100, R2=0.691

# %% [markdown]
# ## Plot

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_learning_curves(result_dict,
                         x_start=900,
                         x_step=100,
                         save_path=None,
                         dpi=300):
    """
    Plot MSE and R2 learning curves. x-axis runs from x_start in steps of x_step,
    exactly matching the length of your recorded curves.
    """
    plt.figure(figsize=(12, 6))

    # ---- Left: MSE ----
    plt.subplot(1, 2, 1)
    for exp_name, results in result_dict.items():
        mse_data = np.array(results["mse"])       # shape (n_runs, n_iters)
        mean_mse = mse_data.mean(axis=0)
        std_mse  = mse_data.std (axis=0)

        # build x so it has exactly len(mean_mse) points
        x = np.arange(x_start, x_start + x_step * len(mean_mse), x_step)

        line = plt.plot(x, mean_mse, label=exp_name)[0]
        plt.fill_between(x,
                         mean_mse - std_mse,
                         mean_mse + std_mse,
                         color=line.get_color(),
                         alpha=0.2)

    plt.xlabel('Number of Samples')
    plt.ylabel('MSE')
    plt.title('MSE Learning Curves')
    plt.legend()
    plt.grid(True, alpha=0.3)

    # ---- Right: R2 ----
    plt.subplot(1, 2, 2)
    for exp_name, results in result_dict.items():
        r2_data  = np.array(results["r2"])
        mean_r2  = r2_data.mean(axis=0)
        std_r2   = r2_data.std (axis=0)

        x = np.arange(x_start, x_start + x_step * len(mean_r2), x_step)

        line = plt.plot(x, mean_r2, label=exp_name)[0]
        plt.fill_between(x,
                         mean_r2 - std_r2,
                         mean_r2 + std_r2,
                         color=line.get_color(),
                         alpha=0.2)

    plt.xlabel('Number of Samples')
    plt.ylabel('R2 Score')
    plt.title('R2 Score Learning Curves')
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    # if save_path:
        # plt.savefig(save_path, dpi=dpi, bbox_inches='tight')
    plt.show()

# %%
import seaborn as sns
sns.set_theme(style="whitegrid", palette="deep")

result_dict = {
    "Passive Learning": {
        "mse": mse_passive,
        "r2": r2_passive
    },
    "Uncertainty Sampling": {
        "mse": mse_uncertainty,
        "r2": r2_uncertainty
    },
    "Density Sampling": {
        "mse": mse_dst,
        "r2": r2_dst
    },
    "EER Sampling": {
        "mse": mse_eer,
        "r2": r2_eer
    },
    "BlackBox":{
        "mse": mse_blackbox,
        "r2": r2_blackbox
    }
}

plot_learning_curves(result_dict, save_path=None)

# %%
# plot the distribution of the IC50 in X_encoded
plt.figure(figsize=(12, 6))
# plt.subplot(1, 1, 1)
plt.hist(y_train, alpha=0.5, label='Train Set', density=True)
plt.hist(y_test, alpha=0.5, label='Test Set', density=True)
plt.hist(y_pool, alpha=0.5, label='Pool Set', density=True)
plt.xlabel('IC50')
plt.ylabel('Frequency')
plt.title('Distribution of IC50 in Train, Test, and Pool Sets')
plt.legend()
plt.tight_layout()
# plt.savefig('./figures/Distribution_of_IC50.png', dpi=300)
plt.show()
# Out:
# /opt/anaconda3/envs/CMU701/lib/python3.12/site-packages/numpy/lib/histograms.py:885: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
